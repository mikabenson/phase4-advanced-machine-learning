# %% [markdown]
# # Implementing Recommendation Engines with Surprise
#
# ## Introduction
#
# This lesson will give you a brief introduction to implementing recommendation engines with a Python library called `surprise`. You'll get a chance to try out multiple different types of collaborative filtering engines, ranging from both basic neighborhood-based methods to matrix factorization methods.

# %% [markdown]
# ## Objectives
# You will be able to:
#
# - Use `surprise`'s built-in reader class to process data to work with recommender algorithms
# - Use `surprise` to create and cross-validate different recommender algorithms
# - Obtain a prediction for a specific user for a particular item

# %% [markdown]
# In this lesson, we'll be working with a dataset built-in to `surprise` called the `jester` dataset. This dataset contains jokes rated by users on a scale of -10 to 10 based off a user's perceived humor level for a given joke. Let's get recommending some jokes!
#
# First, you'll have to load the jokes dataset. You might have to download it first if prompted. Let's investigate the dataset after we load that. In this folder, you'll find the file for the text of jokes if you want to investigate what caliber of human you're dealing with here.

# %%
# here are the relevant library to work with..
# from surprise import Dataset
# from surprise.model_selection import train_test_split

# %%
! pip install scikit surprise
# Out:
# ERROR: Could not find a version that satisfies the requirement scikit (from versions: none)
# ERROR: No matching distribution found for scikit

# %%
from surprise import Dataset
from surprise import Reader
from surprise.model_selection import train_test_split

jokes = Dataset.load_builtin(name="jester")
jokes

# %%
type(jokes)
# Out:
# surprise.dataset.DatasetAutoFolds

# %%
# Split into train and test set
trainset, testset = train_test_split(jokes, test_size=0.2)

# %%
# lets get access to the content on the Train set
# check for the number of users and items 
num_users = trainset.n_users
num_items = trainset.n_items

print("Here are the number of users for each item ", num_users)
print("Here are the number of items for each user", num_items)
# Out:
# Here are the number of users for each item  58782
# Here are the number of items for each user 140

# %% [markdown]
# Notice how there is no `X_train` or `y_train` in our values here. Our only features here are the ratings of other users and items, so we need to keep everything together. What is happening in the train-test split here is that `surprise` is randomly selecting certain $r_{ij}$ for users $u_{i}$ and items $i_{j} $. 80% of the ratings are in the training set and 20% in the test set. Let's investigate `trainset` and `testset` further.

# %%
print("Type trainset :", type(trainset), "\n") # surprise randomly selects certain users ui and items ij
print("Type testset :", type(testset))
# Out:
# Type trainset : <class 'surprise.trainset.Trainset'>
#
# Type testset : <class 'list'>

# %% [markdown]
# Interestingly enough, the values here are of different data types! The `trainset` is still a `surprise` specific data type that is optimized for computational efficiency and the `testset` is a standard Python list - you'll see why when we start making predictions. Let's take a look at how large our `testset` is as well as what's contained in an individual element. A sacrifice of `surprise`'s implementation is that we lose a lot of the exploratory methods that are present with Pandas.

# %%
print(len(testset))

print(testset[0])

# print(len(testset))
# print(testset[0])
# Out:
# 352288
# ('7779', '89', 2.469)

# %% [markdown]
# ## Memory-Based Methods (Neighborhood-Based)
#
# To begin with, we can calculate the more simple neighborhood-based approaches. Some things to keep in mind are what type of similarities you should use. These can all have fairly substantial effects on the overall performance of the model. You'll notice that the API of surprise is very similar to scikit-learn when it comes to model fitting and testing. To begin with, we'll import the modules we'll be using for the neighborhood-based methods.

# %%
from surprise.prediction_algorithms import knns
from surprise.similarities import cosine, msd, pearson
from surprise import accuracy
import numpy as np
np.int = int

# %% [markdown]
# One of our first decisions is item-item similarity versus user-user similarity. For the sake of computation time, it's best to calculate the similarity between whichever number is fewer, users or items. Let's see what the case is for our training set.

# %%
print("Number of users: ", trainset.n_users, "\n")
print("Number of items: ", trainset.n_items, "\n")

# there's way more users than items, since there's fewer items than user its more efficient to calculate item-item similarity rather than user-user
# similarity
# Out:
# Number of users:  58782
#
# Number of items:  140

# %% [markdown]
# There are clearly way more users than items! We'll take that into account when inputting the specifications to our similarity metrics. Because we have fewer items than users, it will be more efficient to calculate item-item similarity rather than user-user similarity.

# %%
# get the cosine similarity
sim_cosine = {'name': 'cosine', 'user_based':  False}
print(sim_cosine)
# sim_cos = {"name": "cosine", "user_based": False}
# Out:
# {'name': 'cosine', 'user_based': False}

# %% [markdown]
# Now it's time to train our model. Note that if you decide to train this model with `user_based=True`, it will take quite some time!

# %%
# lets fit the sim_cosine on the train data using the user_based = False.
# by using the True the training would take a long time to train

base_knn = knns.KNNBasic(sim_options = sim_cosine)
base_knn.fit(trainset)

# basic = knns.KNNBasic(sim_options=sim_cosine)
# basic.fit(trainset)
# Out:
# Computing the cosine similarity matrix...
# Done computing similarity matrix.

# %% [markdown]
# And now our model is fit! Let's take a look at the similarity metrics of each of the items to one another by using the `sim` attribute of our fitted model.

# %%
base_knn.sim

# basic.sim
# Out:
# array([[ 1.        , -0.0342802 ,  0.64296905, ...,  0.51702641,
#          0.42169253,  0.14473167],
#        [-0.0342802 ,  1.        , -0.02909392, ..., -0.13527914,
#         -0.06980483, -0.05806708],
#        [ 0.64296905, -0.02909392,  1.        , ...,  0.70618388,
#          0.59187372,  0.40058678],
#        ...,
#        [ 0.51702641, -0.13527914,  0.70618388, ...,  1.        ,
#          0.57118637,  0.39254659],
#        [ 0.42169253, -0.06980483,  0.59187372, ...,  0.57118637,
#          1.        ,  0.49216551],
#        [ 0.14473167, -0.05806708,  0.40058678, ...,  0.39254659,
#          0.49216551,  1.        ]])

# %% [markdown]
# Now it's time to test the model to determine how well it performed.

# %%
# test the model performance..
preds = base_knn.test(testset)
preds


# predictions = basic.test(testset)
# Out:
# [Prediction(uid='7779', iid='89', r_ui=2.469, est=3.8085283206015688, details={'actual_k': 25, 'was_impossible': False}),
#  Prediction(uid='992', iid='8', r_ui=-0.688, est=0.9075645428674513, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='36748', iid='17', r_ui=2.438, est=3.739647801485279, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='54820', iid='101', r_ui=-9.156, est=-3.190701253511137, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='14902', iid='115', r_ui=9.719, est=4.028341136565893, details={'actual_k': 17, 'was_impossible': False}),
#  Prediction(uid='47474', iid='146', r_ui=0.844, est=-1.4227682894820823, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='40320', iid='143', r_ui=8.562, est=8.29464399130006, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='61050', iid='148', r_ui=-2.219, est=2.553740253899448, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='60260', iid='122', r_ui=8.844, est=2.1802320551307255, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='40267', iid='143', r_ui=5.031, est=3.1040634052407436, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='35856', iid='84', r_ui=9.344, est=7.468257229529716, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='15059', iid='16', r_ui=-4.188, est=-6.7396823709923614, details={'actual_k': 3, 'was_impossible': False}),
#  Prediction(uid='29918', iid='110', r_ui=-9.688, est=-2.780966906938734, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='12388', iid='114', r_ui=6.438, est=6.4281474652132475, details={'actual_k': 27, 'was_impossible': False}),
#  Prediction(uid='30679', iid='23', r_ui=-4.406, est=-2.773551906482431, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='35952', iid='59', r_ui=-3.469, est=-1.654075632842574, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='20575', iid='114', r_ui=7.938, est=6.329605918001171, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='48660', iid='133', r_ui=1.219, est=0.7818900531346729, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='8403', iid='122', r_ui=1.531, est=0.31471036122054574, details={'actual_k': 28, 'was_impossible': False}),
#  Prediction(uid='59369', iid='7', r_ui=9.406, est=9.625, details={'actual_k': 1, 'was_impossible': False}),
#  Prediction(uid='28136', iid='87', r_ui=0.844, est=2.18089714401703, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='4057', iid='148', r_ui=6.188, est=4.175578970502814, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='44032', iid='136', r_ui=5.344, est=4.425137479213862, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='33834', iid='56', r_ui=2.906, est=4.717466892689275, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='59924', iid='104', r_ui=8.688, est=8.349563293659763, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='15531', iid='32', r_ui=0.062, est=-0.6575871587815144, details={'actual_k': 10, 'was_impossible': False}),
#  Prediction(uid='53184', iid='72', r_ui=-3.219, est=3.8586113795064287, details={'actual_k': 15, 'was_impossible': False}),
#  Prediction(uid='49888', iid='48', r_ui=8.25, est=5.498298794672711, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='55345', iid='16', r_ui=0.25, est=0.5863506434125803, details={'actual_k': 7, 'was_impossible': False}),
#  Prediction(uid='37732', iid='104', r_ui=6.781, est=5.256277229785544, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='43554', iid='82', r_ui=-4.281, est=0.20112042727652657, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='35969', iid='8', r_ui=-0.438, est=0.5277015846986558, details={'actual_k': 11, 'was_impossible': False}),
#  Prediction(uid='37374', iid='127', r_ui=4.688, est=5.097248239490443, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='54135', iid='105', r_ui=1.531, est=2.0974876389528556, details={'actual_k': 21, 'was_impossible': False}),
#  Prediction(uid='24507', iid='16', r_ui=-8.656, est=1.0081877166301019, details={'actual_k': 6, 'was_impossible': False}),
#  Prediction(uid='37641', iid='75', r_ui=-7.156, est=-4.403682797139665, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='58112', iid='13', r_ui=-9.781, est=0.3935503238051721, details={'actual_k': 22, 'was_impossible': False}),
#  Prediction(uid='3069', iid='49', r_ui=3.25, est=3.2407387616917225, details={'actual_k': 22, 'was_impossible': False}),
#  Prediction(uid='29534', iid='129', r_ui=2.969, est=5.207792141741643, details={'actual_k': 22, 'was_impossible': False}),
#  Prediction(uid='63070', iid='15', r_ui=9.625, est=-2.6086786293795923, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='45641', iid='92', r_ui=0.562, est=1.8010607221530825, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='33164', iid='8', r_ui=-4.062, est=-0.5824470485629225, details={'actual_k': 23, 'was_impossible': False}),
#  Prediction(uid='31635', iid='17', r_ui=-4.844, est=2.4052311408764755, details={'actual_k': 6, 'was_impossible': False}),
#  Prediction(uid='56861', iid='137', r_ui=0.219, est=0.549116499178066, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='62546', iid='78', r_ui=8.625, est=7.424560789195156, details={'actual_k': 12, 'was_impossible': False}),
#  Prediction(uid='30584', iid='19', r_ui=-5.0, est=-4.468535869982733, details={'actual_k': 9, 'was_impossible': False}),
#  Prediction(uid='24613', iid='68', r_ui=5.531, est=6.581786688136326, details={'actual_k': 23, 'was_impossible': False}),
#  Prediction(uid='34013', iid='37', r_ui=9.188, est=8.761113990181897, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='1710', iid='95', r_ui=-3.219, est=-0.0960598280150377, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='28863', iid='13', r_ui=0.344, est=5.744540753542577, details={'actual_k': 11, 'was_impossible': False}),
#  Prediction(uid='8311', iid='18', r_ui=-1.844, est=1.0243019524303842, details={'actual_k': 28, 'was_impossible': False}),
#  Prediction(uid='32593', iid='122', r_ui=4.875, est=4.935744528391916, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='63351', iid='72', r_ui=0.594, est=0.038117909864982535, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='10469', iid='53', r_ui=1.312, est=3.890615038170451, details={'actual_k': 15, 'was_impossible': False}),
#  Prediction(uid='40444', iid='92', r_ui=9.281, est=-0.3361919898474515, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='33278', iid='19', r_ui=-2.125, est=0.266458525218789, details={'actual_k': 37, 'was_impossible': False}),
#  Prediction(uid='8810', iid='142', r_ui=-8.719, est=-0.896707359643699, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='34002', iid='15', r_ui=5.625, est=0.3808928898350459, details={'actual_k': 13, 'was_impossible': False}),
#  Prediction(uid='34025', iid='21', r_ui=1.969, est=2.6192501768018186, details={'actual_k': 39, 'was_impossible': False}),
#  Prediction(uid='13182', iid='16', r_ui=-4.812, est=2.575241884196197, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='25271', iid='53', r_ui=4.375, est=2.2028039198665588, details={'actual_k': 24, 'was_impossible': False}),
#  Prediction(uid='18090', iid='62', r_ui=-3.906, est=-0.44930661052384585, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='5753', iid='7', r_ui=-5.281, est=1.7673330533015477, details={'actual_k': 6, 'was_impossible': False}),
#  Prediction(uid='41923', iid='114', r_ui=7.25, est=4.057353945725895, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='20696', iid='102', r_ui=-4.906, est=-1.4397103738945791, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='10636', iid='18', r_ui=-2.312, est=-0.7759441629367287, details={'actual_k': 10, 'was_impossible': False}),
#  Prediction(uid='52504', iid='18', r_ui=-7.656, est=-0.9994873965603279, details={'actual_k': 12, 'was_impossible': False}),
#  Prediction(uid='29684', iid='104', r_ui=6.469, est=5.997688636286184, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='63799', iid='16', r_ui=-9.219, est=-7.4305003504056515, details={'actual_k': 7, 'was_impossible': False}),
#  Prediction(uid='57281', iid='13', r_ui=-1.594, est=0.8518812902868985, details={'actual_k': 8, 'was_impossible': False}),
#  Prediction(uid='35551', iid='147', r_ui=8.781, est=8.565889465183082, details={'actual_k': 28, 'was_impossible': False}),
#  Prediction(uid='63166', iid='35', r_ui=1.594, est=5.328504912950133, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='857', iid='78', r_ui=-4.469, est=1.2963594972341255, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='30159', iid='32', r_ui=1.344, est=-0.7273724998890235, details={'actual_k': 22, 'was_impossible': False}),
#  Prediction(uid='46921', iid='83', r_ui=-1.719, est=2.8868539348043765, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='41504', iid='15', r_ui=-4.406, est=-4.863626655448515, details={'actual_k': 9, 'was_impossible': False}),
#  Prediction(uid='34038', iid='135', r_ui=9.656, est=-4.010631203622525, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='42873', iid='19', r_ui=5.281, est=2.339950869015226, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='34646', iid='121', r_ui=3.469, est=0.8431929444339262, details={'actual_k': 13, 'was_impossible': False}),
#  Prediction(uid='56039', iid='117', r_ui=0.531, est=-1.5509944270942484, details={'actual_k': 22, 'was_impossible': False}),
#  Prediction(uid='6321', iid='114', r_ui=7.188, est=5.007109583901941, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='440', iid='61', r_ui=1.594, est=0.7602116924692649, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='37051', iid='18', r_ui=3.219, est=-0.3763545732279519, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='11432', iid='8', r_ui=-8.094, est=0.5045307238377, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='29268', iid='8', r_ui=6.156, est=0.09009789183461261, details={'actual_k': 32, 'was_impossible': False}),
#  Prediction(uid='14200', iid='15', r_ui=-9.375, est=-4.642123618680141, details={'actual_k': 7, 'was_impossible': False}),
#  Prediction(uid='26167', iid='50', r_ui=-3.875, est=0.5086711377711783, details={'actual_k': 27, 'was_impossible': False}),
#  Prediction(uid='16056', iid='145', r_ui=5.344, est=-1.0120319530460808, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='29827', iid='117', r_ui=5.781, est=5.698081283265278, details={'actual_k': 4, 'was_impossible': False}),
#  Prediction(uid='41266', iid='17', r_ui=6.688, est=6.698284343382023, details={'actual_k': 29, 'was_impossible': False}),
#  Prediction(uid='42792', iid='144', r_ui=0.031, est=0.4549630072977828, details={'actual_k': 31, 'was_impossible': False}),
#  Prediction(uid='22135', iid='117', r_ui=5.156, est=6.05083959911092, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='53451', iid='63', r_ui=-4.188, est=-2.410562090733557, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='37905', iid='7', r_ui=5.438, est=-2.2867012971018315, details={'actual_k': 5, 'was_impossible': False}),
#  Prediction(uid='47646', iid='94', r_ui=-2.562, est=2.3806042348244842, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='37732', iid='16', r_ui=-4.281, est=2.942446352542027, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='1776', iid='120', r_ui=9.969, est=9.854543676046315, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='55888', iid='35', r_ui=7.406, est=4.8612252318204225, details={'actual_k': 8, 'was_impossible': False}),
#  Prediction(uid='53949', iid='145', r_ui=9.188, est=8.014053973815672, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='159', iid='97', r_ui=7.281, est=5.225498209820848, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='278', iid='27', r_ui=-5.375, est=5.75475205374805, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='49883', iid='13', r_ui=6.094, est=-1.6498130113088632, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='11971', iid='7', r_ui=5.594, est=1.4118446636872968, details={'actual_k': 6, 'was_impossible': False}),
#  Prediction(uid='9603', iid='122', r_ui=-5.0, est=4.949505900661734, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='43293', iid='53', r_ui=5.656, est=5.843670406227814, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='27705', iid='50', r_ui=9.062, est=4.6631700967094085, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='52549', iid='16', r_ui=6.719, est=0.4073512085286993, details={'actual_k': 7, 'was_impossible': False}),
#  Prediction(uid='48013', iid='37', r_ui=-0.875, est=-0.9925770929072838, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='61405', iid='19', r_ui=-6.094, est=-1.3623091761678483, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='54805', iid='15', r_ui=2.969, est=-1.7491546478173443, details={'actual_k': 5, 'was_impossible': False}),
#  Prediction(uid='34737', iid='122', r_ui=0.281, est=5.799078192245071, details={'actual_k': 37, 'was_impossible': False}),
#  Prediction(uid='62467', iid='56', r_ui=4.469, est=4.21124220373739, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='62154', iid='119', r_ui=3.375, est=3.381947805251028, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='56258', iid='7', r_ui=-0.406, est=0.023164875596683464, details={'actual_k': 6, 'was_impossible': False}),
#  Prediction(uid='18479', iid='56', r_ui=9.781, est=9.322879740074885, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='40403', iid='56', r_ui=2.188, est=2.7771940493078655, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='21891', iid='109', r_ui=1.625, est=3.4437465394285036, details={'actual_k': 16, 'was_impossible': False}),
#  Prediction(uid='57968', iid='54', r_ui=2.062, est=1.6319310039855865, details={'actual_k': 7, 'was_impossible': False}),
#  Prediction(uid='57514', iid='7', r_ui=-7.438, est=2.349289798462524, details={'actual_k': 5, 'was_impossible': False}),
#  Prediction(uid='14820', iid='32', r_ui=5.25, est=5.258704820977848, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='2115', iid='82', r_ui=-1.625, est=-0.8099593202878911, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='36432', iid='143', r_ui=3.969, est=2.0288395002328805, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='17197', iid='114', r_ui=-9.688, est=1.0913851055896513, details={'actual_k': 24, 'was_impossible': False}),
#  Prediction(uid='6003', iid='57', r_ui=8.281, est=6.2061227265145185, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='44235', iid='25', r_ui=-4.469, est=0.6462355281467003, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='53344', iid='32', r_ui=8.5, est=6.840839365721933, details={'actual_k': 16, 'was_impossible': False}),
#  Prediction(uid='58061', iid='140', r_ui=-9.844, est=-8.599860825116131, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='12198', iid='21', r_ui=8.625, est=2.437704092534698, details={'actual_k': 6, 'was_impossible': False}),
#  Prediction(uid='55582', iid='46', r_ui=3.156, est=2.6941367394511158, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='44789', iid='36', r_ui=1.375, est=5.299107200069777, details={'actual_k': 26, 'was_impossible': False}),
#  Prediction(uid='61908', iid='13', r_ui=-0.594, est=1.4985876402107865, details={'actual_k': 18, 'was_impossible': False}),
#  Prediction(uid='10451', iid='7', r_ui=-9.219, est=-9.777210457947634, details={'actual_k': 5, 'was_impossible': False}),
#  Prediction(uid='40743', iid='107', r_ui=3.75, est=2.032680000546162, details={'actual_k': 15, 'was_impossible': False}),
#  Prediction(uid='3766', iid='16', r_ui=-8.062, est=-7.9838143352249515, details={'actual_k': 6, 'was_impossible': False}),
#  Prediction(uid='60847', iid='15', r_ui=5.312, est=-2.1678545896804784, details={'actual_k': 7, 'was_impossible': False}),
#  Prediction(uid='13138', iid='121', r_ui=2.375, est=-1.6376939149256546, details={'actual_k': 10, 'was_impossible': False}),
#  Prediction(uid='60997', iid='7', r_ui=-7.125, est=-5.2942185786375475, details={'actual_k': 6, 'was_impossible': False}),
#  Prediction(uid='54079', iid='150', r_ui=1.656, est=0.30593812009041976, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='31934', iid='38', r_ui=6.969, est=2.037186763219572, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='49262', iid='104', r_ui=2.844, est=1.5643525810573635, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='42328', iid='108', r_ui=-6.156, est=-2.945181840807328, details={'actual_k': 32, 'was_impossible': False}),
#  Prediction(uid='18834', iid='53', r_ui=-0.844, est=1.033394526610143, details={'actual_k': 13, 'was_impossible': False}),
#  Prediction(uid='3896', iid='107', r_ui=9.156, est=0.5409293445274155, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='43358', iid='19', r_ui=5.344, est=5.703526648339543, details={'actual_k': 15, 'was_impossible': False}),
#  Prediction(uid='51309', iid='50', r_ui=4.531, est=-0.07198452283958408, details={'actual_k': 37, 'was_impossible': False}),
#  Prediction(uid='20141', iid='16', r_ui=-1.281, est=-0.22394533197274485, details={'actual_k': 7, 'was_impossible': False}),
#  Prediction(uid='37437', iid='19', r_ui=2.031, est=3.140867884295488, details={'actual_k': 24, 'was_impossible': False}),
#  Prediction(uid='50655', iid='127', r_ui=1.625, est=4.708596371322437, details={'actual_k': 33, 'was_impossible': False}),
#  Prediction(uid='2089', iid='16', r_ui=-9.625, est=-0.823223410042174, details={'actual_k': 11, 'was_impossible': False}),
#  Prediction(uid='47089', iid='81', r_ui=4.812, est=4.740620764137418, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='9767', iid='19', r_ui=-1.438, est=1.0929971142887884, details={'actual_k': 4, 'was_impossible': False}),
#  Prediction(uid='59184', iid='45', r_ui=2.781, est=0.7138729694475241, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='3212', iid='46', r_ui=9.719, est=-5.37650947136581, details={'actual_k': 22, 'was_impossible': False}),
#  Prediction(uid='44232', iid='69', r_ui=5.375, est=1.4430015560042475, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='13774', iid='113', r_ui=-5.406, est=5.024711562483259, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='62751', iid='92', r_ui=6.625, est=2.0595414247548103, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='36444', iid='18', r_ui=5.562, est=2.9850325230061685, details={'actual_k': 12, 'was_impossible': False}),
#  Prediction(uid='36039', iid='137', r_ui=-0.125, est=-3.635063528046968, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='36577', iid='50', r_ui=3.656, est=1.5707198635306714, details={'actual_k': 12, 'was_impossible': False}),
#  Prediction(uid='15295', iid='53', r_ui=-8.938, est=-0.2595419188970478, details={'actual_k': 18, 'was_impossible': False}),
#  Prediction(uid='15552', iid='71', r_ui=-9.344, est=-2.4100424797757998, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='18007', iid='19', r_ui=-8.344, est=2.5075990308902707, details={'actual_k': 31, 'was_impossible': False}),
#  Prediction(uid='31586', iid='71', r_ui=-8.188, est=-3.918660556043288, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='9469', iid='75', r_ui=7.438, est=6.536164911292039, details={'actual_k': 20, 'was_impossible': False}),
#  Prediction(uid='62190', iid='16', r_ui=6.656, est=-0.3169346465541927, details={'actual_k': 5, 'was_impossible': False}),
#  Prediction(uid='8653', iid='98', r_ui=5.062, est=3.9988488534118733, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='54454', iid='18', r_ui=-9.906, est=-5.048132739976468, details={'actual_k': 27, 'was_impossible': False}),
#  Prediction(uid='6153', iid='144', r_ui=7.562, est=3.1664001550561958, details={'actual_k': 16, 'was_impossible': False}),
#  Prediction(uid='21265', iid='17', r_ui=1.625, est=-0.20416037635116982, details={'actual_k': 12, 'was_impossible': False}),
#  Prediction(uid='34149', iid='89', r_ui=4.625, est=5.1768441426293705, details={'actual_k': 32, 'was_impossible': False}),
#  Prediction(uid='18221', iid='8', r_ui=0.562, est=0.6444536744612575, details={'actual_k': 21, 'was_impossible': False}),
#  Prediction(uid='3170', iid='121', r_ui=0.156, est=-2.755478192539161, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='45887', iid='114', r_ui=-3.219, est=-5.330735196047448, details={'actual_k': 9, 'was_impossible': False}),
#  Prediction(uid='39053', iid='68', r_ui=-1.031, est=0.6725117255464883, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='27443', iid='18', r_ui=-1.812, est=-1.4911956322737505, details={'actual_k': 7, 'was_impossible': False}),
#  Prediction(uid='47989', iid='96', r_ui=8.75, est=5.570759074223531, details={'actual_k': 22, 'was_impossible': False}),
#  Prediction(uid='23515', iid='19', r_ui=-5.594, est=-3.173764536958758, details={'actual_k': 7, 'was_impossible': False}),
#  Prediction(uid='43082', iid='107', r_ui=3.031, est=2.92030849838773, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='25994', iid='26', r_ui=0.594, est=1.6389572813266828, details={'actual_k': 22, 'was_impossible': False}),
#  Prediction(uid='7678', iid='138', r_ui=6.625, est=4.811759070598819, details={'actual_k': 12, 'was_impossible': False}),
#  Prediction(uid='10139', iid='63', r_ui=3.219, est=1.562973046518764, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='17636', iid='108', r_ui=4.406, est=3.0649085413261923, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='32762', iid='131', r_ui=-1.625, est=4.09607724064357, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='1612', iid='103', r_ui=-9.5, est=-6.327928463704715, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='46864', iid='140', r_ui=-6.969, est=4.979910179946174, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='56167', iid='88', r_ui=-3.625, est=-1.6413476654622523, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='37409', iid='47', r_ui=5.312, est=6.555617137538644, details={'actual_k': 31, 'was_impossible': False}),
#  Prediction(uid='21947', iid='117', r_ui=-3.844, est=-2.0369821209731054, details={'actual_k': 25, 'was_impossible': False}),
#  Prediction(uid='12180', iid='50', r_ui=7.094, est=4.9015020863314325, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='57420', iid='19', r_ui=1.75, est=1.2573364412083465, details={'actual_k': 27, 'was_impossible': False}),
#  Prediction(uid='58745', iid='63', r_ui=-9.562, est=-5.639830267845739, details={'actual_k': 7, 'was_impossible': False}),
#  Prediction(uid='31989', iid='104', r_ui=9.906, est=9.412743819350329, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='11210', iid='142', r_ui=9.938, est=9.361516094806587, details={'actual_k': 14, 'was_impossible': False}),
#  Prediction(uid='44408', iid='64', r_ui=7.094, est=3.2456393245771094, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='40561', iid='128', r_ui=0.281, est=1.4186395404850174, details={'actual_k': 27, 'was_impossible': False}),
#  Prediction(uid='39255', iid='87', r_ui=-6.25, est=-3.989160836650336, details={'actual_k': 28, 'was_impossible': False}),
#  Prediction(uid='59315', iid='39', r_ui=1.656, est=1.7275407873679416, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='36884', iid='139', r_ui=9.938, est=5.714508979911069, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='48997', iid='148', r_ui=-0.031, est=2.1775939500561754, details={'actual_k': 29, 'was_impossible': False}),
#  Prediction(uid='46980', iid='133', r_ui=4.781, est=7.5647767292239445, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='28246', iid='28', r_ui=2.688, est=3.0163596825464363, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='10849', iid='54', r_ui=2.312, est=2.2526934558598533, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='26386', iid='13', r_ui=-4.5, est=4.007358639023836, details={'actual_k': 7, 'was_impossible': False}),
#  Prediction(uid='2648', iid='72', r_ui=1.438, est=1.537993586710918, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='49985', iid='118', r_ui=-2.25, est=-0.5968647885040721, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='48926', iid='54', r_ui=5.125, est=0.09819130826695718, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='38287', iid='18', r_ui=4.562, est=2.7748176714828956, details={'actual_k': 5, 'was_impossible': False}),
#  Prediction(uid='29417', iid='88', r_ui=-8.219, est=7.798598068109951, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='35748', iid='30', r_ui=2.188, est=3.093671204442324, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='47089', iid='136', r_ui=3.281, est=6.116660526815006, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='1884', iid='129', r_ui=9.719, est=1.6522185120203272, details={'actual_k': 14, 'was_impossible': False}),
#  Prediction(uid='46444', iid='106', r_ui=1.156, est=-0.6900977913746612, details={'actual_k': 14, 'was_impossible': False}),
#  Prediction(uid='35134', iid='125', r_ui=1.156, est=0.46914814986410175, details={'actual_k': 9, 'was_impossible': False}),
#  Prediction(uid='33090', iid='122', r_ui=4.25, est=3.1298481958844317, details={'actual_k': 18, 'was_impossible': False}),
#  Prediction(uid='44929', iid='94', r_ui=3.469, est=2.737035970545736, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='47105', iid='17', r_ui=-7.656, est=-3.508025398649673, details={'actual_k': 10, 'was_impossible': False}),
#  Prediction(uid='29062', iid='8', r_ui=-6.469, est=1.6699569599279553, details={'actual_k': 16, 'was_impossible': False}),
#  Prediction(uid='39969', iid='119', r_ui=7.5, est=4.702123517715029, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='48926', iid='58', r_ui=-5.719, est=-1.0736736282585393, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='7752', iid='76', r_ui=6.781, est=3.7983698304704783, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='4894', iid='53', r_ui=4.406, est=3.392304732630434, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='33238', iid='78', r_ui=8.625, est=8.241673504318799, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='4255', iid='18', r_ui=-6.812, est=-7.359220570277568, details={'actual_k': 26, 'was_impossible': False}),
#  Prediction(uid='54497', iid='65', r_ui=-0.188, est=1.3492166897778892, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='5282', iid='45', r_ui=5.875, est=6.211897939688678, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='43731', iid='144', r_ui=-3.531, est=-3.800910734082322, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='59609', iid='29', r_ui=5.062, est=3.3490608874349217, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='36196', iid='21', r_ui=8.656, est=0.03788338224750152, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='14567', iid='130', r_ui=8.719, est=7.478238726814645, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='56235', iid='137', r_ui=5.094, est=3.479045516487186, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='53914', iid='133', r_ui=-0.594, est=-0.7177935767423633, details={'actual_k': 32, 'was_impossible': False}),
#  Prediction(uid='25105', iid='141', r_ui=-7.344, est=-2.9221050339488555, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='7175', iid='103', r_ui=-3.938, est=-2.4699378959136618, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='38848', iid='139', r_ui=4.094, est=-0.9932638755609716, details={'actual_k': 11, 'was_impossible': False}),
#  Prediction(uid='53950', iid='13', r_ui=2.844, est=-0.9738619251812689, details={'actual_k': 8, 'was_impossible': False}),
#  Prediction(uid='1200', iid='18', r_ui=-2.312, est=-6.2200274152436865, details={'actual_k': 5, 'was_impossible': False}),
#  Prediction(uid='14728', iid='22', r_ui=3.375, est=2.5137541674799495, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='60828', iid='109', r_ui=5.625, est=2.74075555802315, details={'actual_k': 20, 'was_impossible': False}),
#  Prediction(uid='5799', iid='8', r_ui=-2.219, est=0.36504700209829627, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='39383', iid='109', r_ui=1.688, est=4.531364626349487, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='17612', iid='36', r_ui=4.125, est=1.801615200107692, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='34074', iid='119', r_ui=4.625, est=2.9325106872164772, details={'actual_k': 24, 'was_impossible': False}),
#  Prediction(uid='58368', iid='129', r_ui=8.562, est=6.784188117594243, details={'actual_k': 19, 'was_impossible': False}),
#  Prediction(uid='937', iid='148', r_ui=-8.906, est=-8.956718461695452, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='11169', iid='7', r_ui=-3.219, est=-0.8717287860150317, details={'actual_k': 2, 'was_impossible': False}),
#  Prediction(uid='32205', iid='63', r_ui=6.5, est=3.9717988017092023, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='18747', iid='83', r_ui=8.781, est=7.513634616449636, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='53382', iid='62', r_ui=1.75, est=0.8654394060954532, details={'actual_k': 37, 'was_impossible': False}),
#  Prediction(uid='14506', iid='148', r_ui=3.031, est=-0.7090248712406948, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='9105', iid='8', r_ui=-5.656, est=2.077661373580532, details={'actual_k': 17, 'was_impossible': False}),
#  Prediction(uid='17708', iid='18', r_ui=2.594, est=0.6905870952991701, details={'actual_k': 7, 'was_impossible': False}),
#  Prediction(uid='35761', iid='79', r_ui=-1.969, est=-0.16236258164399878, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='44610', iid='8', r_ui=-1.531, est=-1.424899204108362, details={'actual_k': 7, 'was_impossible': False}),
#  Prediction(uid='31624', iid='147', r_ui=-5.75, est=6.101557346298654, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='37276', iid='91', r_ui=-8.688, est=-0.04336017382031822, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='16001', iid='106', r_ui=6.656, est=1.458754774755655, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='14849', iid='46', r_ui=-8.062, est=-0.1982711180249244, details={'actual_k': 16, 'was_impossible': False}),
#  Prediction(uid='53363', iid='89', r_ui=9.219, est=1.3363142358377536, details={'actual_k': 28, 'was_impossible': False}),
#  Prediction(uid='63815', iid='19', r_ui=2.375, est=2.40701187934721, details={'actual_k': 32, 'was_impossible': False}),
#  Prediction(uid='42615', iid='56', r_ui=-4.906, est=-1.7813857689790762, details={'actual_k': 12, 'was_impossible': False}),
#  Prediction(uid='6006', iid='113', r_ui=9.812, est=8.876580781459166, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='45288', iid='112', r_ui=-2.031, est=0.18144883930004863, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='38392', iid='150', r_ui=-1.719, est=1.5330939169952633, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='1734', iid='30', r_ui=-6.625, est=-0.5177324280913714, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='44925', iid='78', r_ui=3.125, est=2.3163770183083052, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='31957', iid='143', r_ui=0.875, est=3.7920264569540225, details={'actual_k': 27, 'was_impossible': False}),
#  Prediction(uid='42407', iid='144', r_ui=8.719, est=4.45925409130702, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='29944', iid='28', r_ui=9.031, est=5.649876834416425, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='5372', iid='76', r_ui=7.719, est=6.0388063858824665, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='34877', iid='107', r_ui=1.375, est=2.7583009647242904, details={'actual_k': 9, 'was_impossible': False}),
#  Prediction(uid='31086', iid='35', r_ui=0.406, est=-0.44250965160505257, details={'actual_k': 20, 'was_impossible': False}),
#  Prediction(uid='10194', iid='131', r_ui=3.031, est=-0.3917379912348022, details={'actual_k': 21, 'was_impossible': False}),
#  Prediction(uid='49636', iid='19', r_ui=-6.188, est=-3.388902754029315, details={'actual_k': 9, 'was_impossible': False}),
#  Prediction(uid='62409', iid='35', r_ui=-0.781, est=3.8002194106912786, details={'actual_k': 31, 'was_impossible': False}),
#  Prediction(uid='59381', iid='55', r_ui=1.75, est=0.024973146262472896, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='63544', iid='7', r_ui=-6.156, est=0.8420614369391003, details={'actual_k': 38, 'was_impossible': False}),
#  Prediction(uid='37847', iid='135', r_ui=4.719, est=0.12145151483704916, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='7100', iid='56', r_ui=-3.531, est=3.1317873520930037, details={'actual_k': 24, 'was_impossible': False}),
#  Prediction(uid='3154', iid='139', r_ui=-7.5, est=-6.774001959913354, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='45701', iid='103', r_ui=2.344, est=-1.355820221978715, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='8866', iid='107', r_ui=4.906, est=2.456943151362671, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='9013', iid='111', r_ui=7.438, est=6.5311472008048534, details={'actual_k': 38, 'was_impossible': False}),
#  Prediction(uid='35369', iid='103', r_ui=-1.031, est=-3.3884991219684366, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='62767', iid='19', r_ui=-6.688, est=-0.8643342193996384, details={'actual_k': 12, 'was_impossible': False}),
#  Prediction(uid='42648', iid='69', r_ui=1.625, est=1.4012536897631398, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='19897', iid='76', r_ui=8.094, est=5.258579475669578, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='29992', iid='129', r_ui=7.531, est=1.8368809186687394, details={'actual_k': 22, 'was_impossible': False}),
#  Prediction(uid='43083', iid='34', r_ui=3.281, est=1.283023573665593, details={'actual_k': 17, 'was_impossible': False}),
#  Prediction(uid='29862', iid='104', r_ui=6.688, est=5.699591816981711, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='60655', iid='55', r_ui=9.688, est=9.142859791367725, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='15320', iid='32', r_ui=-8.938, est=-3.23057654251273, details={'actual_k': 15, 'was_impossible': False}),
#  Prediction(uid='58184', iid='120', r_ui=-2.406, est=0.4017007970214507, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='38431', iid='74', r_ui=2.312, est=1.6373482744094505, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='44243', iid='24', r_ui=-0.219, est=-0.8429759372230591, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='40189', iid='89', r_ui=-9.375, est=-4.840323036218347, details={'actual_k': 11, 'was_impossible': False}),
#  Prediction(uid='31819', iid='50', r_ui=1.156, est=1.1743710770809266, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='44875', iid='98', r_ui=7.5, est=6.165609383612256, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='34675', iid='60', r_ui=2.969, est=0.3297319824251561, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='1051', iid='78', r_ui=-2.75, est=-4.256658844880211, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='23775', iid='104', r_ui=4.281, est=2.398634404925764, details={'actual_k': 18, 'was_impossible': False}),
#  Prediction(uid='22090', iid='18', r_ui=3.906, est=3.7878839020192165, details={'actual_k': 7, 'was_impossible': False}),
#  Prediction(uid='60320', iid='130', r_ui=1.719, est=5.411950986433313, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='7374', iid='127', r_ui=9.125, est=6.702419240636183, details={'actual_k': 11, 'was_impossible': False}),
#  Prediction(uid='35122', iid='97', r_ui=-5.062, est=0.6467845264704051, details={'actual_k': 7, 'was_impossible': False}),
#  Prediction(uid='7181', iid='15', r_ui=2.406, est=1.7919851754724712, details={'actual_k': 2, 'was_impossible': False}),
#  Prediction(uid='4129', iid='114', r_ui=-8.875, est=-6.339227671165669, details={'actual_k': 13, 'was_impossible': False}),
#  Prediction(uid='28068', iid='108', r_ui=0.969, est=3.6589114398083993, details={'actual_k': 35, 'was_impossible': False}),
#  Prediction(uid='49388', iid='60', r_ui=-8.75, est=-1.4927673745084509, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='23841', iid='23', r_ui=-3.438, est=-0.28271812087246706, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='56759', iid='112', r_ui=-4.188, est=-0.27328219732211095, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='427', iid='53', r_ui=1.594, est=0.38647990248619635, details={'actual_k': 21, 'was_impossible': False}),
#  Prediction(uid='46235', iid='146', r_ui=6.438, est=7.585344313749336, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='19940', iid='141', r_ui=-1.719, est=0.05649526988294864, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='21170', iid='22', r_ui=1.781, est=1.2596019874021596, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='60764', iid='7', r_ui=6.438, est=3.991392605675317, details={'actual_k': 6, 'was_impossible': False}),
#  Prediction(uid='54732', iid='50', r_ui=-9.469, est=-3.47636298706195, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='60348', iid='132', r_ui=6.0, est=5.62157942647004, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='8458', iid='17', r_ui=-8.406, est=2.8309482508967188, details={'actual_k': 12, 'was_impossible': False}),
#  Prediction(uid='57781', iid='48', r_ui=-2.531, est=-4.606703510974853, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='38308', iid='104', r_ui=-0.594, est=1.905417374995883, details={'actual_k': 11, 'was_impossible': False}),
#  Prediction(uid='35878', iid='149', r_ui=-4.188, est=2.0877849383188463, details={'actual_k': 17, 'was_impossible': False}),
#  Prediction(uid='11703', iid='60', r_ui=-9.688, est=-4.955674514863, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='2579', iid='133', r_ui=1.625, est=2.6919150029676833, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='11502', iid='36', r_ui=2.844, est=2.2224587329113783, details={'actual_k': 32, 'was_impossible': False}),
#  Prediction(uid='41317', iid='19', r_ui=5.031, est=3.9440604700494317, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='12569', iid='145', r_ui=6.562, est=2.9508075989154636, details={'actual_k': 8, 'was_impossible': False}),
#  Prediction(uid='22878', iid='120', r_ui=-2.531, est=3.2968266317474404, details={'actual_k': 36, 'was_impossible': False}),
#  Prediction(uid='5535', iid='29', r_ui=5.094, est=3.404636869578782, details={'actual_k': 38, 'was_impossible': False}),
#  Prediction(uid='50937', iid='16', r_ui=-2.094, est=-3.250801060225952, details={'actual_k': 6, 'was_impossible': False}),
#  Prediction(uid='57233', iid='150', r_ui=3.656, est=2.942303041313603, details={'actual_k': 14, 'was_impossible': False}),
#  Prediction(uid='14136', iid='56', r_ui=9.688, est=6.485707081292923, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='9989', iid='30', r_ui=1.156, est=1.1615429518753189, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='12095', iid='83', r_ui=0.562, est=0.9756038081146156, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='4773', iid='95', r_ui=2.625, est=0.5237592327993309, details={'actual_k': 26, 'was_impossible': False}),
#  Prediction(uid='12427', iid='111', r_ui=1.594, est=0.07376328790619432, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='48359', iid='50', r_ui=9.469, est=9.035629313582193, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='52091', iid='89', r_ui=5.906, est=3.407892152691624, details={'actual_k': 17, 'was_impossible': False}),
#  Prediction(uid='37287', iid='28', r_ui=-2.625, est=-1.0689983914417307, details={'actual_k': 18, 'was_impossible': False}),
#  Prediction(uid='19290', iid='15', r_ui=3.25, est=3.733724321640637, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='17337', iid='121', r_ui=1.125, est=3.421157944621958, details={'actual_k': 35, 'was_impossible': False}),
#  Prediction(uid='49940', iid='47', r_ui=6.375, est=1.9799236680479164, details={'actual_k': 22, 'was_impossible': False}),
#  Prediction(uid='16697', iid='7', r_ui=-6.0, est=-7.254132878014122, details={'actual_k': 5, 'was_impossible': False}),
#  Prediction(uid='42226', iid='133', r_ui=-2.625, est=2.8330961880964125, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='30347', iid='17', r_ui=-4.625, est=-0.11846029327004634, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='18772', iid='15', r_ui=-5.562, est=-0.6030739059955159, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='11401', iid='7', r_ui=-1.938, est=-0.5565841881274703, details={'actual_k': 5, 'was_impossible': False}),
#  Prediction(uid='10264', iid='34', r_ui=5.656, est=6.021893413224394, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='16175', iid='7', r_ui=-3.344, est=-2.133194513940671, details={'actual_k': 36, 'was_impossible': False}),
#  Prediction(uid='10262', iid='17', r_ui=9.5, est=6.499225373180751, details={'actual_k': 17, 'was_impossible': False}),
#  Prediction(uid='6340', iid='44', r_ui=-7.688, est=0.43467978156470166, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='54695', iid='8', r_ui=-2.438, est=3.1532612041183956, details={'actual_k': 37, 'was_impossible': False}),
#  Prediction(uid='46702', iid='60', r_ui=0.188, est=4.424007163512, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='7570', iid='79', r_ui=-1.875, est=3.1854619193276266, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='62030', iid='69', r_ui=1.281, est=3.414860983302169, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='63692', iid='19', r_ui=-5.719, est=-0.7973956391671198, details={'actual_k': 14, 'was_impossible': False}),
#  Prediction(uid='37030', iid='22', r_ui=-9.531, est=7.9336311176554775, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='35446', iid='81', r_ui=1.594, est=3.8532424380686754, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='23917', iid='16', r_ui=0.25, est=-0.12267842606146681, details={'actual_k': 10, 'was_impossible': False}),
#  Prediction(uid='54767', iid='93', r_ui=3.312, est=2.051138961372747, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='40460', iid='66', r_ui=3.562, est=4.6484635032830335, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='47467', iid='32', r_ui=-3.156, est=1.3810526978548134, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='42684', iid='63', r_ui=-9.344, est=-7.71110541666155, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='45106', iid='15', r_ui=-4.719, est=-0.5000922633156999, details={'actual_k': 6, 'was_impossible': False}),
#  Prediction(uid='3515', iid='145', r_ui=-0.125, est=0.40578815417821773, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='33410', iid='117', r_ui=0.906, est=0.856237142140774, details={'actual_k': 5, 'was_impossible': False}),
#  Prediction(uid='48974', iid='91', r_ui=-6.375, est=1.1784548926463878, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='1136', iid='102', r_ui=-2.156, est=2.326647630846893, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='1234', iid='148', r_ui=6.0, est=4.412672408871458, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='20942', iid='17', r_ui=2.969, est=-2.6833566796394295, details={'actual_k': 23, 'was_impossible': False}),
#  Prediction(uid='46487', iid='41', r_ui=-7.188, est=1.8508395836543368, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='45912', iid='96', r_ui=3.094, est=-0.7824532844889164, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='12277', iid='127', r_ui=-4.344, est=-2.6271697790776862, details={'actual_k': 33, 'was_impossible': False}),
#  Prediction(uid='35601', iid='16', r_ui=8.312, est=8.687206979263294, details={'actual_k': 12, 'was_impossible': False}),
#  Prediction(uid='3442', iid='55', r_ui=-8.969, est=-7.998359040800784, details={'actual_k': 8, 'was_impossible': False}),
#  Prediction(uid='2417', iid='119', r_ui=-4.281, est=0.7055102510737379, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='47776', iid='143', r_ui=3.562, est=-0.6420108041931972, details={'actual_k': 13, 'was_impossible': False}),
#  Prediction(uid='63144', iid='92', r_ui=8.25, est=7.988320872796431, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='29379', iid='50', r_ui=9.438, est=8.33087147320995, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='42050', iid='21', r_ui=3.375, est=-0.629720585672097, details={'actual_k': 34, 'was_impossible': False}),
#  Prediction(uid='3334', iid='62', r_ui=2.906, est=5.85973655472758, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='47995', iid='132', r_ui=-1.844, est=3.551243414559652, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='8201', iid='7', r_ui=3.594, est=-3.8922897864158053, details={'actual_k': 8, 'was_impossible': False}),
#  Prediction(uid='51905', iid='16', r_ui=4.719, est=-1.2271379035865344, details={'actual_k': 4, 'was_impossible': False}),
#  Prediction(uid='51866', iid='58', r_ui=-3.719, est=-1.6569427244851331, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='45288', iid='58', r_ui=-1.281, est=1.0021603534229142, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='39227', iid='56', r_ui=-1.75, est=2.501991624451549, details={'actual_k': 30, 'was_impossible': False}),
#  Prediction(uid='37912', iid='139', r_ui=-1.188, est=6.910985669931601, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='41946', iid='94', r_ui=-3.594, est=-1.7717455748004796, details={'actual_k': 29, 'was_impossible': False}),
#  Prediction(uid='63076', iid='119', r_ui=4.969, est=2.413998851221868, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='43607', iid='107', r_ui=-2.625, est=1.636570770348324, details={'actual_k': 40, 'was_impossible': False}),
# ...
#  Prediction(uid='23530', iid='78', r_ui=5.688, est=4.975803461083115, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='35640', iid='44', r_ui=4.281, est=-1.568579679159308, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='20512', iid='112', r_ui=2.562, est=0.07937700107422509, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='63236', iid='15', r_ui=-2.25, est=3.6902008432338356, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='61944', iid='135', r_ui=3.125, est=4.143555462677941, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='53976', iid='16', r_ui=8.75, est=4.977878433253767, details={'actual_k': 15, 'was_impossible': False}),
#  Prediction(uid='2202', iid='96', r_ui=7.656, est=7.593005270806991, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='13617', iid='8', r_ui=-3.469, est=-4.930215755771184, details={'actual_k': 10, 'was_impossible': False}),
#  Prediction(uid='48272', iid='104', r_ui=-4.719, est=-0.24609287704749916, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='58562', iid='149', r_ui=-7.406, est=-4.868725935980208, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='17252', iid='15', r_ui=-3.281, est=-1.0284332016324043, details={'actual_k': 8, 'was_impossible': False}),
#  Prediction(uid='34559', iid='53', r_ui=5.75, est=5.443702095610028, details={'actual_k': 16, 'was_impossible': False}),
#  Prediction(uid='25966', iid='138', r_ui=0.312, est=6.617150908746012, details={'actual_k': 35, 'was_impossible': False}),
#  Prediction(uid='36648', iid='130', r_ui=2.031, est=1.89053734286182, details={'actual_k': 38, 'was_impossible': False}),
#  Prediction(uid='13633', iid='133', r_ui=-0.219, est=6.221252973122388, details={'actual_k': 30, 'was_impossible': False}),
#  Prediction(uid='10096', iid='59', r_ui=-6.688, est=-0.026071479374132893, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='25537', iid='19', r_ui=-9.875, est=-0.7069634167028293, details={'actual_k': 6, 'was_impossible': False}),
#  Prediction(uid='52383', iid='105', r_ui=2.156, est=-1.2774979123339174, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='6892', iid='95', r_ui=-3.719, est=-0.9470820217964613, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='20245', iid='28', r_ui=-9.906, est=6.321742879409942, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='54782', iid='110', r_ui=9.406, est=8.300517588130768, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='9412', iid='141', r_ui=-3.562, est=-0.5967716135009815, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='18838', iid='75', r_ui=-8.719, est=-4.831503246287814, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='35660', iid='138', r_ui=4.719, est=2.6187254951825945, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='1995', iid='134', r_ui=-4.344, est=-4.890955106934988, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='8444', iid='78', r_ui=-0.469, est=3.7955047938394997, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='11849', iid='17', r_ui=-1.5, est=-6.3637621925801575, details={'actual_k': 6, 'was_impossible': False}),
#  Prediction(uid='52213', iid='29', r_ui=8.938, est=5.206484494833394, details={'actual_k': 30, 'was_impossible': False}),
#  Prediction(uid='41115', iid='111', r_ui=3.188, est=0.513641110304001, details={'actual_k': 32, 'was_impossible': False}),
#  Prediction(uid='44941', iid='60', r_ui=6.094, est=5.712398084647588, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='30178', iid='13', r_ui=-8.094, est=-1.9086829680490967, details={'actual_k': 30, 'was_impossible': False}),
#  Prediction(uid='11889', iid='45', r_ui=6.938, est=6.861083157305687, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='12470', iid='19', r_ui=8.281, est=-2.1766059648013965, details={'actual_k': 7, 'was_impossible': False}),
#  Prediction(uid='54190', iid='17', r_ui=8.188, est=5.6054939508444, details={'actual_k': 38, 'was_impossible': False}),
#  Prediction(uid='33453', iid='56', r_ui=5.688, est=5.360165684873349, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='46183', iid='148', r_ui=3.281, est=2.747259391317118, details={'actual_k': 34, 'was_impossible': False}),
#  Prediction(uid='3290', iid='104', r_ui=-0.562, est=-0.33335088492819137, details={'actual_k': 28, 'was_impossible': False}),
#  Prediction(uid='48684', iid='29', r_ui=9.938, est=7.146459820310322, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='50191', iid='109', r_ui=5.188, est=3.74191858760071, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='42139', iid='112', r_ui=9.031, est=8.009690848966688, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='2381', iid='18', r_ui=5.031, est=1.2865502024945856, details={'actual_k': 13, 'was_impossible': False}),
#  Prediction(uid='63478', iid='36', r_ui=-7.438, est=-0.5944343584246294, details={'actual_k': 36, 'was_impossible': False}),
#  Prediction(uid='29919', iid='104', r_ui=5.375, est=6.784007296048305, details={'actual_k': 22, 'was_impossible': False}),
#  Prediction(uid='54225', iid='40', r_ui=1.438, est=3.5296868406349047, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='52125', iid='135', r_ui=9.938, est=9.959704002820345, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='30588', iid='93', r_ui=9.812, est=6.525396187808981, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='11703', iid='90', r_ui=-8.656, est=-3.1488272567425497, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='40716', iid='21', r_ui=3.812, est=3.810753904535321, details={'actual_k': 29, 'was_impossible': False}),
#  Prediction(uid='3255', iid='105', r_ui=2.031, est=1.4130599893260054, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='2495', iid='42', r_ui=0.219, est=-0.6453975228058836, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='57051', iid='15', r_ui=4.031, est=-6.645052350496005, details={'actual_k': 8, 'was_impossible': False}),
#  Prediction(uid='8625', iid='70', r_ui=-3.719, est=1.026870628205647, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='3112', iid='146', r_ui=-4.5, est=1.0348734444235232, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='12284', iid='93', r_ui=-0.844, est=-0.5156462029495924, details={'actual_k': 32, 'was_impossible': False}),
#  Prediction(uid='16387', iid='17', r_ui=4.781, est=6.145922988628473, details={'actual_k': 7, 'was_impossible': False}),
#  Prediction(uid='36244', iid='143', r_ui=0.375, est=4.307041893398237, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='19335', iid='8', r_ui=-8.406, est=1.197718251382463, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='47954', iid='72', r_ui=4.844, est=5.58208341552515, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='27261', iid='18', r_ui=-0.656, est=-5.217573743520584, details={'actual_k': 6, 'was_impossible': False}),
#  Prediction(uid='40980', iid='106', r_ui=2.125, est=-5.558670689922214, details={'actual_k': 24, 'was_impossible': False}),
#  Prediction(uid='19520', iid='133', r_ui=4.812, est=4.584824704284438, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='20895', iid='25', r_ui=9.406, est=7.9051591290575915, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='2121', iid='132', r_ui=7.344, est=4.296639239293136, details={'actual_k': 10, 'was_impossible': False}),
#  Prediction(uid='56575', iid='129', r_ui=6.938, est=1.1968054511716506, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='1774', iid='35', r_ui=7.688, est=5.107147071373716, details={'actual_k': 36, 'was_impossible': False}),
#  Prediction(uid='49689', iid='15', r_ui=6.188, est=4.441172418334383, details={'actual_k': 29, 'was_impossible': False}),
#  Prediction(uid='35458', iid='127', r_ui=-1.094, est=-1.1387505019964268, details={'actual_k': 12, 'was_impossible': False}),
#  Prediction(uid='7387', iid='60', r_ui=7.219, est=5.3425207461249435, details={'actual_k': 27, 'was_impossible': False}),
#  Prediction(uid='1458', iid='128', r_ui=2.844, est=4.078259418144412, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='28301', iid='15', r_ui=6.344, est=0.12401642958913649, details={'actual_k': 6, 'was_impossible': False}),
#  Prediction(uid='36745', iid='65', r_ui=0.062, est=0.03898057937304381, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='43424', iid='66', r_ui=1.094, est=1.0798753547285973, details={'actual_k': 8, 'was_impossible': False}),
#  Prediction(uid='11781', iid='29', r_ui=3.719, est=4.554926339509692, details={'actual_k': 23, 'was_impossible': False}),
#  Prediction(uid='14504', iid='24', r_ui=-9.0, est=-1.24857647532563, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='57409', iid='143', r_ui=9.344, est=3.5713661830437187, details={'actual_k': 29, 'was_impossible': False}),
#  Prediction(uid='33565', iid='121', r_ui=9.812, est=5.350372353225486, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='9331', iid='8', r_ui=-5.812, est=0.09947185948058763, details={'actual_k': 15, 'was_impossible': False}),
#  Prediction(uid='35989', iid='50', r_ui=3.781, est=4.814609208637134, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='2329', iid='15', r_ui=8.625, est=2.933423510061321, details={'actual_k': 8, 'was_impossible': False}),
#  Prediction(uid='53084', iid='110', r_ui=7.5, est=6.07268419425986, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='6303', iid='62', r_ui=2.375, est=1.945863087172362, details={'actual_k': 10, 'was_impossible': False}),
#  Prediction(uid='46355', iid='138', r_ui=-6.438, est=2.9293277825953363, details={'actual_k': 26, 'was_impossible': False}),
#  Prediction(uid='18480', iid='118', r_ui=4.344, est=3.6796656570598163, details={'actual_k': 26, 'was_impossible': False}),
#  Prediction(uid='53353', iid='139', r_ui=0.812, est=0.3069757343220699, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='32205', iid='81', r_ui=-9.875, est=2.6813661844728465, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='63557', iid='7', r_ui=-9.594, est=1.783456609474047, details={'actual_k': 7, 'was_impossible': False}),
#  Prediction(uid='16305', iid='150', r_ui=5.125, est=7.357979733252246, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='10447', iid='95', r_ui=5.188, est=5.069393460599619, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='18220', iid='120', r_ui=4.312, est=2.281599411804213, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='23439', iid='15', r_ui=-4.062, est=3.339818771315564, details={'actual_k': 5, 'was_impossible': False}),
#  Prediction(uid='15104', iid='21', r_ui=9.844, est=6.368392906084554, details={'actual_k': 10, 'was_impossible': False}),
#  Prediction(uid='51273', iid='19', r_ui=0.719, est=3.59909898713786, details={'actual_k': 15, 'was_impossible': False}),
#  Prediction(uid='47891', iid='103', r_ui=4.844, est=3.006639823020334, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='50873', iid='7', r_ui=-2.625, est=-0.5483540417717279, details={'actual_k': 6, 'was_impossible': False}),
#  Prediction(uid='43742', iid='8', r_ui=-6.094, est=-2.7758739604087204, details={'actual_k': 20, 'was_impossible': False}),
#  Prediction(uid='31022', iid='107', r_ui=10.0, est=3.117314133818569, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='7744', iid='13', r_ui=3.969, est=-1.9682007630024523, details={'actual_k': 18, 'was_impossible': False}),
#  Prediction(uid='42871', iid='150', r_ui=4.906, est=2.5887273940082047, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='31406', iid='138', r_ui=0.062, est=-2.4544749813994247, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='13557', iid='34', r_ui=9.438, est=4.809016985757773, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='6042', iid='101', r_ui=-9.188, est=-8.19020158657898, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='16543', iid='17', r_ui=9.812, est=9.580886408003797, details={'actual_k': 6, 'was_impossible': False}),
#  Prediction(uid='54574', iid='46', r_ui=1.312, est=0.6813910414054943, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='34232', iid='102', r_ui=4.812, est=1.5133081830391202, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='56834', iid='8', r_ui=3.375, est=0.274628182110414, details={'actual_k': 33, 'was_impossible': False}),
#  Prediction(uid='31460', iid='127', r_ui=8.281, est=2.746353002722255, details={'actual_k': 23, 'was_impossible': False}),
#  Prediction(uid='27374', iid='89', r_ui=4.156, est=1.250517285481382, details={'actual_k': 3, 'was_impossible': False}),
#  Prediction(uid='32523', iid='147', r_ui=1.562, est=-0.6660010703661623, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='32809', iid='35', r_ui=0.5, est=4.34830727129954, details={'actual_k': 11, 'was_impossible': False}),
#  Prediction(uid='33240', iid='105', r_ui=-1.781, est=2.722832440697137, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='41625', iid='48', r_ui=-9.719, est=-1.537454424459104, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='626', iid='111', r_ui=-2.062, est=0.32127668990155467, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='31224', iid='78', r_ui=-0.625, est=3.0051343245776314, details={'actual_k': 27, 'was_impossible': False}),
#  Prediction(uid='12281', iid='145', r_ui=9.25, est=9.25023842455172, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='13726', iid='108', r_ui=2.25, est=1.6798698004991424, details={'actual_k': 21, 'was_impossible': False}),
#  Prediction(uid='593', iid='97', r_ui=-1.156, est=-1.0510466044458546, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='31562', iid='128', r_ui=6.625, est=1.105158014224433, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='46962', iid='139', r_ui=-0.5, est=0.42136726585056367, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='33495', iid='109', r_ui=0.375, est=2.773326639114508, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='31160', iid='29', r_ui=3.094, est=2.386761613487289, details={'actual_k': 9, 'was_impossible': False}),
#  Prediction(uid='12490', iid='112', r_ui=1.75, est=-2.129665215875782, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='56635', iid='32', r_ui=3.469, est=3.485911565992229, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='47235', iid='136', r_ui=3.906, est=3.2228663259337673, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='61408', iid='113', r_ui=-2.219, est=-0.11209910221380973, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='42576', iid='129', r_ui=7.312, est=7.3167854702518484, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='24732', iid='8', r_ui=9.125, est=-1.2789330436388446, details={'actual_k': 6, 'was_impossible': False}),
#  Prediction(uid='34099', iid='8', r_ui=1.656, est=1.121453873290585, details={'actual_k': 13, 'was_impossible': False}),
#  Prediction(uid='3272', iid='19', r_ui=-2.469, est=2.3633312537800157, details={'actual_k': 21, 'was_impossible': False}),
#  Prediction(uid='40518', iid='19', r_ui=-7.688, est=0.9559033606961056, details={'actual_k': 12, 'was_impossible': False}),
#  Prediction(uid='61122', iid='102', r_ui=7.969, est=2.4904291436662613, details={'actual_k': 40, 'was_impossible': False}),
#  ...]

# %%
# check for the accuracy score
print(accuracy.rmse(preds))

# the model has rmse value of 4.2165 which ,means that its off by roughly 4 points for each random guess it made for the rating

# print(accuracy.rmse(predictions))
# Out:
# RMSE: 4.2165
# 4.216494349912535

# %% [markdown]
# Not a particularly amazing model.... As you can see, the model had an RMSE of about 4.5, meaning that it was off by roughly 4 points for each guess it made for ratings. Not horrendous when you consider we're working on a range of 20 points, but let's see if we can improve it. To begin with, let's try with a different similarity metric (Pearson correlation) and evaluate our RMSE.

# %%
# use the pearson similarity then evaluate its performance..
sim_pearson = {'name': 'pearson', 'user_based': False}
base_knn_pearson = knns.KNNBasic(sim_options = sim_pearson)

# fit the model on the test set
base_knn_pearson.fit(trainset)

# get the predictions
pred_1 = base_knn_pearson.test(testset)

# evaluate the accuracy score on the pearson similarity..
print(accuracy.rmse(pred_1))

# the pearson similarity has performed better than the cosine similarity in the base KNN mode
# Out:
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 4.2775
# 4.2775298117369545

# %%
# sim_pearson = {"name": "pearson", "user_based": False}
# basic_pearson = knns.KNNBasic(sim_options=sim_pearson)
# basic_pearson.fit(trainset)
# predictions = basic_pearson.test(testset)
# print(accuracy.rmse(predictions))
# Out:
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 4.2775
# 4.2775298117369545

# %% [markdown]
# Pearson correlation seems to have performed better than cosine similarity in the basic KNN model, we can go ahead and use Pearson correlation as our similarity metric of choice for future models. The next model we're going to try is [KNN with Means](https://surprise.readthedocs.io/en/stable/knn_inspired.html#surprise.prediction_algorithms.knns.KNNWithMeans). This is the same thing as the basic KNN model, except it takes into account the mean rating of each user or item depending on whether you are performing user-user or item-item similarities, respectively.

# %%
# lets try using the KNN with means which involves taking into account the mean rating of each user or item depending on whether 
# you're performing user-user or item-item similarities..
sim_pearson = {'name': 'pearson', 'user_based': False}
knn_mean = knns.KNNWithMeans(sim_options = sim_pearson)

# fitting the model
knn_mean.fit(trainset)
pred_2 = knn_mean.test(testset)

print(accuracy.rmse(pred_2))
# Out:
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 4.1365
# 4.136476380648139

# %%
# sim_pearson = {"name": "pearson", "user_based": False}
# knn_means = knns.KNNWithMeans(sim_options=sim_pearson)
# knn_means.fit(trainset)
# predictions = knn_means.test(testset)
# print(accuracy.rmse(predictions))

# %% [markdown]
# A little better... let's try one more neighborhood-based method before moving into model-based methods. Let's try the [KNNBaseline](https://surprise.readthedocs.io/en/stable/knn_inspired.html#surprise.prediction_algorithms.knns.KNNBaseline) method. This is a more advanced method because it adds in a bias term that is calculated by way of minimizing a cost function represented by:
#
# $$ \sum_{r_{ui} \in R_{\text{train}}}{(\hat{r}_{ui} - ( \mu + b_{i} + b_{u}))^{2} + \lambda(b_u^2 + b_i^2) } $$
#
# With $b_i$ and $b_u$ being biases for items and users respectively and $\mu$ referring to the global mean.

# %%
sim_pearson = {"name": "pearson", "user_based": False}
knn_baseline = knns.KNNBaseline(sim_options=sim_pearson)
knn_baseline.fit(trainset)
predictions = knn_baseline.test(testset)
print(accuracy.rmse(predictions))
# Out:
# Estimating biases using als...
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 4.1322
# 4.132202989811008

# %% [markdown]
# Even better! Now let's see if we can get some insight by applying some matrix factorization techniques!

# %% [markdown]
# ## Model-Based Methods (Matrix Factorization)
#
# It's worth pointing out that when SVD is calculated for recommendation systems, it is preferred to be done with a modified version called "Funk's SVD" that only takes into account the rated values, ignoring whatever items have not been rated by users. The algorithm is named after Simon Funk, who was part of the team who placed 3rd in the Netflix challenge with this innovative way of performing matrix decomposition. Read more about Funk's SVD implementation at [his original blog post](https://sifter.org/~simon/journal/20061211.html). There is no simple way to include for this fact with SciPy's implementation of `svd()`, but luckily the `surprise` library has Funk's version of SVD implemented to make our lives easier!
#
# Similar to other `sklearn` features, we can expedite the process of trying out different parameters by using an implementation of grid search. Let's make use of the grid search here to account for some different configurations of parameters within the SVD pipeline. This might take some time! You'll notice that the `n_jobs` is parameter set to -1, which ensures that all of the cores on your computer will be used to process fitting and evaluating all of these models. To help keep track of what is occurring here, take note of the different values. This code ended up taking over 16 minutes to complete even with parallelization in effect, so the optimal parameters are given to you for the SVD model below. Use them to train a model and let's see how well it performs. If you want the full grid search experience, feel free to uncomment the code and give it a go!
#
# The optimal parameters are :
#
# ```python
# {'n_factors': 100, 'n_epochs': 10, 'lr_all': 0.005, 'reg_all': 0.4}
#
# ```

# %%
from surprise.prediction_algorithms import SVD
from surprise.model_selection import GridSearchCV

# param_grid = {'n_factors':[20, 100],'n_epochs': [5, 10], 'lr_all': [0.002, 0.005],
#               'reg_all': [0.4, 0.6]}
# gs_model = GridSearchCV(SVD,param_grid=param_grid,n_jobs = -1,joblib_verbose=5)
# gs_model.fit(jokes)

# %%
svd = SVD(n_factors = 100, n_epochs = 10, lr_all = 0.005, reg_all = 0.4)

# fit the algorithm on the test set..
svd.fit(trainset)

# get the predictions
pred_3 = svd.test(testset)
print(accuracy.rmse(pred_3))
# Out:
# RMSE: 4.2774
# 4.277398789443669

# %%
# svd = SVD(n_factors=100, n_epochs=10, lr_all=0.005, reg_all=0.4)
# svd.fit(trainset)
# predictions = svd.test(testset)
# print(accuracy.rmse(predictions))
# Out:
# RMSE: 4.2704
# 4.270431174267582

# %% [markdown]
# Interestingly, this model performed worse than the others! In general, the advantages of matrix factorization starts to show itself when the size of the dataset becomes massive. At that point, the storage challenges increase for the memory-based models, and there is enough data for latent factors to become extremely apparent.

# %% [markdown]
# ## Making Predictions
#
# Now that we've explored some models, we can think about how we might fit the models into the context of an application. To begin with, let's access some basic functionality of `surprise` models to get predicted ratings for a given user and item. All that's needed are the `user_id` and `item_id` for which you want to make a prediction. Here we're making a prediction for user 34 and item 25 using the SVD model we just fit.

# %%
user_34_prediction = svd.predict("34", "25")
user_34_prediction
# Out:
# Prediction(uid='34', iid='25', r_ui=None, est=2.204309697654434, details={'was_impossible': False})

# %% [markdown]
# The output of the prediction is a tuple. Here, we're going to access the estimated rating.

# %%
user_34_prediction[3]
# Out:
# 2.204309697654434

# %% [markdown]
# You might be wondering, "OK I'm making predictions about certain items rated by certain users, but how can I actually give certain N recommendations to an individual user?" Although `surprise`  is a great library, it does not have this recommendation functionality built into it, but in the next lab, you will get some experience not only fitting recommendation system models, but also programmatically retrieving recommended items for each user.

# %% [markdown]
# ### Sources
#
#
# Jester dataset originally obtained from:
#
# [Eigentaste](http://www.ieor.berkeley.edu/~goldberg/pubs/eigentaste.pdf): A Constant Time Collaborative Filtering Algorithm. Ken Goldberg, Theresa Roeder, Dhruv Gupta, and Chris Perkins. Information Retrieval, 4(2), 133-151. July 2001.

# %% [markdown]
# ### Additional Resources
#
# - [Surprise Documentation](https://surprise.readthedocs.io/en/stable/index.html)
# - [Surprise Tutorial](https://blog.cambridgespark.com/tutorial-practical-introduction-to-recommender-systems-dbe22848392b)

# %% [markdown]
# ## Summary
#
# You now should have an understanding of the basic considerations one should take note of when coding a recommendation system as well as how to implement them in different ways using `surprise`. In the upcoming lab, you will be tasked with fitting models using `surprise` and then retrieving those predicted values in a meaningful way to give recommendations to people. Let's see how well it works in action.
